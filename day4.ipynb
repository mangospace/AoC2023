# %%
import regex as re
with open('day4.txt', 'r') as f:
    matom=f.readlines()
tot1=0
nummatch=[]
for x in matom:
    matom1=re.sub("Card \d:","", x)
    matom1=re.sub("\n","", matom1)
    matom2=matom1.split("|")
    print(matom2)
    for index, z in enumerate(matom2):
        if index % 2 ==0:
            list1=z.split(" ")
            while("" in list1):
                list1.remove("")
        else:
            list2=z.split(" ")
            while("" in list2):
                list2.remove("")
    print((set(list2).intersection(set(list1))))
    
    ans1=len(set(list2).intersection(set(list1)))
    nummatch.append(ans1)

#    if ans1 == 1:  
#        print("1 find")  
#        ans1 = 0  

#    tot1+=2**ans1

    if ans1 == 1:  
        print("1 find")  
        ans1 = 0  


    elif ans1 == 2:  
        print("2 find")  
        tot1 += 2  

    elif ans1 == 3:  
        print("3 find")  
        tot1 += 4  

    elif ans1 == 4:  
        print("4 find")  
        tot1 += 8  

    elif ans1 == 5:  
        print("5 find")  
        tot1 += 16  

    elif ans1 == 6:  
        print("6 find")  
        tot1 += 32
         
    elif ans1 == 7:  
        print("6 find")  
        tot1 += 64 

    elif ans1 == 8:  
        print("6 find")  
        tot1 += 128 
    
    elif ans1 == 9:  
        print("6 find")  
        tot1 += 256 

    elif ans1 == 10:  
        print("6 find")  
        tot1 += 512 


print(tot1) 
print(max(nummatch))
# Out:
# ['Card   1: 82 15 37 75 85 51 99 18 17  2 ', '  8 17 54 14 18 99  4 85 51 49 91 15 82 24 75 25 69 61 52 58 37 87  2 22 28']
# {'85', '18', '51', '99', '17', '82', '2', '75', '37', '15'}
# 6 find
# ['Card   2: 67 26 84 63 48 73 36 94 89 65 ', ' 36 94 96 65 89 87 12 26 81 82 77 99 40 63  6 73 55 48 10 69 59 78 24 67 84']
# {'48', '67', '94', '73', '89', '63', '36', '84', '65', '26'}
# 6 find
# ['Card   3: 57 44 28 69 45 17 48 62 93 89 ', ' 44 92 33 24 40 43 89 94 62 19 78 87 70 28 57 14 74 32 80 18  8 85 79  9 71']
# {'89', '28', '62', '57', '44'}
# 5 find
# ['Card   4: 74 18 96 80 53 40 72 89 26 84 ', ' 77 53 50 72 88 27 46 26 74 89 39 79 90 57 81 80 92 84 64 21 42 45 76 40 18']
# {'74', '18', '72', '89', '80', '40', '84', '53', '26'}
# 6 find
# ['Card   5: 90 53 63 16 45 84 80 86 71 36 ', ' 84 57 67 63 87 36 78  1 53 51 26 90 58 71 86 44 11 30 47 95 16 55 45 80 15']
# {'86', '90', '63', '80', '36', '45', '84', '71', '53', '16'}
# 6 find
# ...

# %%
    if ans1 == 1:  
        print("1 find")  
        tot1 += 1  

    elif ans1 == 2:  
        print("2 find")  
        tot1 += 2  

    elif ans1 == 3:  
        print("3 find")  
        tot1 += 4  

    elif ans1 == 4:  
        print("4 find")  
        tot1 += 8  

    elif ans1 == 5:  
        print("5 find")  
        tot1 += 16  

    elif ans1 == 6:  
        print("6 find")  
        tot1 += 32
         
    elif ans1 == 7:  
        print("6 find")  
        tot1 += 64 

    elif ans1 == 8:  
        print("6 find")  
        tot1 += 128 
    
    elif ans1 == 9:  
        print("6 find")  
        tot1 += 256 

    elif ans1 == 10:  
        print("6 find")  
        tot1 += 512 


print(tot1)
# Out:
# line='.854...........................................................................362...........271...732........838.........24................'
# line='...*.............................117*...........459........767*648....#.........*...................................$...&..=................'
# line='....970.........368.124.+............57................653...........723.....366....*443..60.........536....441....45..879.....789...*......'
# line='...........749*...-...+..330.....................215%...*................725.....953........%.................*............639......331.419.'
# line='.......706.....59.............*....=...262.............678...........857.*............189....................912.+589.846*...*..............'
# line='..........*................393.59..418....*................151...........594...........*....584*258.......................17.997............'
# ...
